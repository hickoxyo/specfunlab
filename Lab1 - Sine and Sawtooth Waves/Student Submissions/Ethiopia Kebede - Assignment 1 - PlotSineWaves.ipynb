# %% [markdown]
# ## Assignment1 - Plot square or saw-tooth wave
# Hint: Sine waves can be combined to construct a periodic function
# ### Ethiopia Kebede
# #### NOTE: Submit this file as "yourname-assignment1.ipynb" to Moodle after completing the assignment
#
# #### Start by writing a program to plot a sine wave. Use duration from -$\pi$ to  $\pi$ and a certain frequency. Add sine waves with different frequencies until your plot resembles either a square wave or a saw-tooth wave.

# %%
# Include all imports in this cell
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define constants in this cell
#samples per second 
s=800 
#amplitude
a=3.5
#frequency
f=1
#duration
d=(-np.pi, np.pi)

# %%
# Calculate time values (t) and sin(t)
#calculate t
t=np.linspace(-np.pi, np.pi, 2*s) #or t=np.linspace(*d, 2*s)
#calculate sin
y=a*np.sin(2*np.pi*f*t)

# %%
# Put your plot statements here
p=plt.plot(t,y)
plt.xlabel("seconds")
plt.ylabel("amplitude")
plt.title("Sine Wave")
# Out:
# Text(0.5, 1.0, 'Sine Wave')

# %%
#define a second sine wave
y2=np.sin(2*np.pi*3*f*t)
p=plt.plot(t,y+y2)

# %%
#define sine waves
y3=1*np.sin(2*np.pi*2*f*t)
p=plt.plot(t,y+y3)

# %%
#sine wave 4
y4=2*np.sin(2*np.pi*1*f*t)
p=plt.plot(t,y+y4+y3)

# %%
#sine wave 5
y5=3*np.sin(2*np.pi*3*f*t)
p=plt.plot(t,y+y2+y3)

# %%
#define sine waves to be added
w1=1*np.sin(2*np.pi*1*f*t)
w2=0.5*np.sin(2*np.pi*2*f*t)
w3=0.33*np.sin(2*np.pi*3*f*t)
w4=0.25*np.sin(2*np.pi*4*f*t)
w5=0.20*np.sin(2*np.pi*5*f*t)
w6=1/6*np.sin(2*np.pi*6*f*t)
w7=1/7*np.sin(2*np.pi*7*f*t)
w8=1/8*np.sin(2*np.pi*8*f*t)
w9=1/9*np.sin(2*np.pi*9*f*t)
w10=0.1*np.sin(2*np.pi*10*f*t)
#plot
p=plt.plot(t,w1+w2+w3+w4+w5+w6+w7+w8+w9+w10) 

#label
plt.xlabel("seconds")
plt.ylabel("amplitude")
plt.title("Saw Tooth Wave")
# Out:
# Text(0.5, 1.0, 'Saw Tooth Wave')

# %%
#define sine waves to be added
w1=1*np.sin(2*np.pi*1*f*t)
w2=0.5*np.sin(2*np.pi*2*f*t)
w3=0.33*np.sin(2*np.pi*3*f*t)
w4=0.25*np.sin(2*np.pi*4*f*t)
w5=0.20*np.sin(2*np.pi*5*f*t)
w6=1/6*np.sin(2*np.pi*6*f*t)
w7=1/7*np.sin(2*np.pi*7*f*t)
w8=1/8*np.sin(2*np.pi*8*f*t)
w9=1/9*np.sin(2*np.pi*9*f*t)
w10=0.1*np.sin(2*np.pi*10*f*t)
w11 =(1/11)*np.sin(2*np.pi*11*f*t)
w13 =(1/13)*np.sin(2*np.pi*13*f*t)
w15 =(1/15)*np.sin(2*np.pi*15*f*t)
w17 =(1/17)*np.sin(2*np.pi*17*f*t)
w19 =(1/19)*np.sin(2*np.pi*19*f*t)
w21 =(1/21)*np.sin(2*np.pi*21*f*t)
w23 =(1/23)*np.sin(2*np.pi*23*f*t)
w25 =(1/25)*np.sin(2*np.pi*25*f*t)
w27 =(1/27)*np.sin(2*np.pi*27*f*t)
#plot
p=plt.plot(t,w1+w3+w5+w7+w9+w11+w13+w15+w17+w19+w21+w23+w25+w27) 

#title
plt.xlabel("seconds")
plt.ylabel("amplitude")
plt.title("Square Wave")
# Out:
# Text(0.5, 1.0, 'Square Wave')
